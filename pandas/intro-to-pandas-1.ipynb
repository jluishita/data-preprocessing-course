# %% [markdown]
# ## Intro to Pandas
#
# In this tutorial we will see the basic methods of Pandas and how to use them to represent a dataset and extract some information from the data.
#
# Download the following dataset from kaggle.com:
#
# https://www.kaggle.com/spscientist/students-performance-in-exams

# %%
# Import Pandas
import pandas as pd

# %%
# Load the dataset from the csv file, creating a DataFrame object called df
df = pd.read_csv('StudentsPerformance.csv')

# %%
# Show the first 5 rows of df
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Show the last 5 rows of df
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# The number of rows to be shown may be changed
# Show the first 12 rows of df
df.head(12)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# 2                     none          90             95             93
# 3                     none          47             57             44
# 4                     none          76             78             75
# 5                     none          71             83             78
# 6                completed          88             95             92
# 7                     none          40             43             39
# 8                completed          64             64             67
# 9                     none          38             60             50
# 10                    none          58             54             52
# 11                    none          40             52             43

# %%
# Get the list of the column's names
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# Get the list of indices
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# The columns may be renamed.
#
# In this example, the first letter of each variable is written as a capital letter

# %%
# We first define the array of new names
new_columns = ['Gender', 'Race/Ethnicity', 'Parental level of education', 'Lunch',
               'Test preparation course', 'Math score', 'Reading score', 'Writing score']

# Then assign the array of new names to the columns of the DataFrame
df.columns = new_columns

# Let us print the new DataFrame to check that the columns are renamed
df.head()
# Out:
#    Gender Race/Ethnicity Parental level of education         Lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   Test preparation course  Math score  Reading score  Writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Some basic information about the variables can be extracted using the method info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       1000 non-null   object
#  1   Race/Ethnicity               1000 non-null   object
#  2   Parental level of education  1000 non-null   object
#  3   Lunch                        1000 non-null   object
#  4   Test preparation course      1000 non-null   object
#  5   Math score                   1000 non-null   int64
#  6   Reading score                1000 non-null   int64
#  7   Writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# In this example, it can be seen that all the variables, except for the last three ones, are considered object-type. In Pandas' method info(), strings are considered object-type.
#
# It can be noticed that the last three ones are considered integer-type.
#
# Other possible types are, for example, float-type and datetime-type.
#
# There is a column called 'Non-Null Count'. This is a count of how many instances in this column are neither empty values nor NaN (Not-a-Number). It is sometimes usefull to spot the presence of missing values, but it is not an irrefutable test, since sometimes missing values can be marked by special characters or by meaningless numerical values

# %%
# We can extract statistical information from the numerical attributes by using the method describe()
df.describe()
# Out:
#        Math score  Reading score  Writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# In the table of results, we find different rows:
# - The first one shows the count of numerical values in each variable
# - The second one shows the mean of the numerical values for each variable
# - The third one shows the standard deviation for each variable, which gives an idea of the dispersion of the numerical values
# - The fourth one shows the minimum value found for each variable
# - The fifth, sixth and seventh ones show the first, second and third quartiles, respectively.
# - The last one shows the maximum value found for each variable

# %%
# We can reorder the DataFrame by index, for example in reverse order
df.sort_index(axis=0, ascending=False)
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     Test preparation course  Math score  Reading score  Writing score
# 999                    none          77             86             86
# 998               completed          68             78             77
# 997               completed          59             71             65
# 996                    none          62             55             55
# 995               completed          88             99             95
# ..                      ...         ...            ...            ...
# 4                      none          76             78             75
# 3                      none          47             57             44
# 2                      none          90             95             93
# 1                 completed          69             90             88
# 0                      none          72             72             74
#
# [1000 rows x 8 columns]

# %%
# We can also reorder the DataFrame with respect to the values of some variable
df.sort_values(by='Math score')
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 625               completed         100             97             99
# 623               completed         100             96             86
# 451                    none         100             92             97
# 962                    none         100            100            100
# 149               completed         100            100             93
#
# [1000 rows x 8 columns]

# %%
# Or, in reverse order
df.sort_values(by='Math score', ascending=False)
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# Note that these reorderings do not modify the original DataFrame
df
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# We can define a new DataFrame that respects the new ordering
df_ordered = df.sort_values(by='Math score', ascending=False)

# Now print the new DataFrame to check that it is properly defined
df_ordered
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# Alternatively, we can modify the original DataFrame inplace, to avoid creating new DataFrames
df.sort_values(by='Math score', ascending=False, inplace=True)

# Now print the original DataFrame to check that it is properly defined
df
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Selection by label

# %%
# We can select a specific column of df
df['Lunch']
# Out:
# 962        standard
# 625        standard
# 458        standard
# 623        standard
# 451        standard
#            ...
# 145    free/reduced
# 787        standard
# 17     free/reduced
# 980    free/reduced
# 59     free/reduced
# Name: Lunch, Length: 1000, dtype: object

# %%
# To inspect all the possible values of this variable, we can use the unique() method
df['Lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
# If the variable name has no empty spaces, it can also be accessed by
df.Lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
# We can select multiple columns of df
df[['Gender', 'Lunch', 'Test preparation course', 'Math score']]
# Out:
#      Gender         Lunch Test preparation course  Math score
# 962  female      standard                    none         100
# 625    male      standard               completed         100
# 458  female      standard                    none         100
# 623    male      standard               completed         100
# 451  female      standard                    none         100
# ..      ...           ...                     ...         ...
# 145  female  free/reduced                    none          22
# 787  female      standard                    none          19
# 17   female  free/reduced                    none          18
# 980  female  free/reduced                    none           8
# 59   female  free/reduced                    none           0
#
# [1000 rows x 4 columns]

# %%
# We can select a specific row of df
df.loc[0]
# Out:
# Gender                                    female
# Race/Ethnicity                           group B
# Parental level of education    bachelor's degree
# Lunch                                   standard
# Test preparation course                     none
# Math score                                    72
# Reading score                                 72
# Writing score                                 74
# Name: 0, dtype: object

# %% [markdown]
# In this example, we have not selected the first row of df, but the row with index=0

# %%
# We can select multiple rows
df.loc[[0,1]]
# Out:
#    Gender Race/Ethnicity Parental level of education     Lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   Test preparation course  Math score  Reading score  Writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %% [markdown]
# If we use the indexing format df.loc[0,1] we do not only obtain these two rows, but also all the rows placed in between them

# %%
df.loc[0:1]
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 0    female        group B           bachelor's degree      standard
# 83     male        group E          associate's degree      standard
# 814  female        group C                 high school      standard
# 964    male        group D                some college      standard
# 955    male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 828  female        group D            some high school  free/reduced
# 23   female        group C            some high school      standard
# 759    male        group B                some college      standard
# 649  female        group D                some college      standard
# 1    female        group C                some college      standard
#
#     Test preparation course  Math score  Reading score  Writing score
# 0                      none          72             72             74
# 83                     none          72             64             63
# 814                    none          72             80             83
# 964                    none          72             57             58
# 955                    none          72             57             62
# ..                      ...         ...            ...            ...
# 828               completed          69             86             81
# 23                     none          69             73             73
# 759               completed          69             77             77
# 649               completed          69             79             81
# 1                 completed          69             90             88
#
# [67 rows x 8 columns]

# %% [markdown]
# This is because the DataFrame has been sorted by the 'Math score' variable, and index 1 is no longer right after index 0.
#
# If we reorder the DataFrame, we can see that the previous indexing method is now valid.

# %%
df.sort_index(axis=0, inplace=True)

df.loc[0:1]
# Out:
#    Gender Race/Ethnicity Parental level of education     Lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   Test preparation course  Math score  Reading score  Writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
# We can select both rows and columns
df.loc[1:5, ['Gender', 'Lunch', 'Test preparation course', 'Math score']]
# Out:
#    Gender         Lunch Test preparation course  Math score
# 1  female      standard               completed          69
# 2  female      standard                    none          90
# 3    male  free/reduced                    none          47
# 4    male      standard                    none          76
# 5  female      standard                    none          71

# %% [markdown]
# Using a colon returns all the possible values. For example, if we want all the possible rows of ['Gender','Lunch']

# %%
df.loc[:, ['Gender', 'Lunch']]
# Out:
#      Gender         Lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Selection by position

# %% [markdown]
# Instead of using .loc, we can use .iloc

# %%
# With iloc[0], we now obtain the first element of the DataFrame
df.iloc[0]
# Out:
# Gender                                    female
# Race/Ethnicity                           group B
# Parental level of education    bachelor's degree
# Lunch                                   standard
# Test preparation course                     none
# Math score                                    72
# Reading score                                 72
# Writing score                                 74
# Name: 0, dtype: object

# %% [markdown]
# We can check that if we sort the DataFrame, iloc[0] returns the first element of the sorted DataFrame.
#
# Now the result does not depend on the index value.

# %%
df.sort_values(by='Math score', ascending=False, inplace=True)

df.iloc[0]
# Out:
# Gender                                     female
# Race/Ethnicity                            group E
# Parental level of education    associate's degree
# Lunch                                    standard
# Test preparation course                      none
# Math score                                    100
# Reading score                                 100
# Writing score                                 100
# Name: 962, dtype: object

# %%
# To get a specific value we can type
df.iloc[0]['Parental level of education']
# Out:
# "associate's degree"

# %%
# Now, columns are also referred by position
# If we want to select the Gender and Lunch variables for the first intance of the DataFrame
df.iloc[0, [0, 3]]
# Out:
# Gender      female
# Lunch     standard
# Name: 962, dtype: object

# %%
# Or, to select multiple instances
df.iloc[[0, 2, 5, 7], [0, 3]]
# Out:
#      Gender         Lunch
# 962  female      standard
# 458  female      standard
# 149    male  free/reduced
# 263  female      standard

# %%
# Here, we can also use the [a:b] indexing
df.iloc[0:7, 0:5]
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 149    male        group E          associate's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
#
#     Test preparation course
# 962                    none
# 625               completed
# 458                    none
# 623               completed
# 451                    none
# 149               completed
# 916               completed

# %% [markdown]
# ### Boolean indexing
#
# We can select instances that fulfil a certain condition for some of its variables.
#
# For example, we can select all the insatnces for which 'Parental level of education' is 'bachelor's degree'.

# %%
df[df['Parental level of education']=="bachelor's degree"]
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 114  female        group E           bachelor's degree      standard
# 855  female        group B           bachelor's degree      standard
# 562    male        group C           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 174  female        group C           bachelor's degree  free/reduced
# 862    male        group D           bachelor's degree  free/reduced
# 616  female        group E           bachelor's degree      standard
# 455    male        group C           bachelor's degree  free/reduced
# 528  female        group D           bachelor's degree  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 458                    none         100            100            100
# 916               completed         100            100            100
# 114               completed          99            100            100
# 855                    none          97             97             96
# 562               completed          96             90             92
# ..                      ...         ...            ...            ...
# 174               completed          43             51             54
# 862               completed          39             42             38
# 616                    none          37             45             38
# 455                    none          37             56             47
# 528                    none          29             41             47
#
# [118 rows x 8 columns]

# %% [markdown]
# Note that we needed the " character instead of the ' one, because the variable name had already a ' character in it.
#
# Formally, what we did is defining a mask, and then applying the mask to the DataFrame df

# %%
# Let us define the mask
df['Parental level of education']=="bachelor's degree"
# Out:
# 962    False
# 625    False
# 458     True
# 623    False
# 451    False
#        ...
# 145    False
# 787    False
# 17     False
# 980    False
# 59     False
# Name: Parental level of education, Length: 1000, dtype: bool

# %% [markdown]
# When typing df[mask], we are selecting all the instances of df for whick mask has a value 'True'.
#
# We can filter by multiple criteria. For example, we may want to select all the instances for which 'Parental level of education' is equal to "bachelor's degree" and 'Reading score' is above 80

# %%
df[(df['Parental level of education']=="bachelor's degree") & (df['Reading score'] > 80)]
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 114  female        group E           bachelor's degree      standard
# 855  female        group B           bachelor's degree      standard
# 562    male        group C           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 612    male        group C           bachelor's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 571    male        group A           bachelor's degree      standard
# 784    male        group C           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 702    male        group A           bachelor's degree      standard
# 551    male        group B           bachelor's degree  free/reduced
# 509  female        group C           bachelor's degree      standard
# 426    male        group C           bachelor's degree      standard
# 334  female        group C           bachelor's degree      standard
# 234    male        group C           bachelor's degree      standard
# 493  female        group C           bachelor's degree      standard
# 241  female        group E           bachelor's degree      standard
# 700  female        group E           bachelor's degree      standard
# 456  female        group D           bachelor's degree      standard
# 120  female        group C           bachelor's degree      standard
# 821  female        group D           bachelor's degree  free/reduced
# 117  female        group D           bachelor's degree      standard
# 347  female        group C           bachelor's degree      standard
# 189  female        group C           bachelor's degree      standard
# 667  female        group B           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 116  female        group B           bachelor's degree  free/reduced
# 831  female        group C           bachelor's degree  free/reduced
# 232  female        group B           bachelor's degree      standard
# 535  female        group C           bachelor's degree  free/reduced
# 645  female        group B           bachelor's degree      standard
#
#     Test preparation course  Reading score  Writing score
# 458                    none            100            100
# 916               completed            100            100
# 114               completed            100            100
# 855                    none             97             96
# 562               completed             90             92
# 165               completed            100            100
# 612               completed             90             91
# 903               completed            100            100
# 566               completed            100            100
# 594               completed            100             99
# 571                    none             96             92
# 784               completed             81             79
# 970                    none            100            100
# 702               completed             84             87
# 551               completed             90             88
# 509                    none             92             87
# 426                    none             83             86
# 334                    none             93             95
# 234               completed             82             84
# 493                    none             88             90
# 241                    none             83             83
# 700               completed             81             82
# 456                    none             89             89
# 120               completed             92             89
# 821                    none             90             93
# 117                    none             82             79
# 347               completed             94             95
# 189                    none             88             87
# 667                    none             85             87
# 969                    none             84             80
# 116                    none             85             82
# 831               completed             86             89
# 232                    none             86             83
# 535               completed             83             83
# 645               completed             81             81

# %% [markdown]
# It is possible to select a specific column of the filtered df. For example, let us select the variable 'Lunch' from the previous result

# %%
df[(df['Parental level of education']=="bachelor's degree") & (df['Reading score'] > 80)]['Lunch']
# Out:
# 458        standard
# 916        standard
# 114        standard
# 855        standard
# 562        standard
# 165        standard
# 612        standard
# 903    free/reduced
# 566    free/reduced
# 594        standard
# 571        standard
# 784        standard
# 970        standard
# 702        standard
# 551    free/reduced
# 509        standard
# 426        standard
# 334        standard
# 234        standard
# 493        standard
# 241        standard
# 700        standard
# 456        standard
# 120        standard
# 821    free/reduced
# 117        standard
# 347        standard
# 189        standard
# 667    free/reduced
# 969        standard
# 116    free/reduced
# 831    free/reduced
# 232        standard
# 535    free/reduced
# 645        standard
# Name: Lunch, dtype: object

# %% [markdown]
# What we obtain here is not a Pandas DataFrame, but a Pandas Series.
#
# If we want to count the number of instances for each of the possible values of the variable 'Lunch', we can use the value_counts() method

# %%
mask = (df['Parental level of education']=="bachelor's degree") & (df['Reading score'] > 80)
df[mask]['Lunch'].value_counts()
# Out:
# standard        27
# free/reduced     8
# Name: Lunch, dtype: int64

# %% [markdown]
# We have seen here that, among all the cases for which the parental level of education is "bachelor's degree" and the reading score is above 80, there are 27 instances for which the variable Lunch has a value 'standard' and 8 instances for which the variable 'Lunch' has a value 'free/reduced'
#
# # This can help us understand the dataset

# %% [markdown]
# ### Drop columns

# %%
# In some situations, we may want to remove a column.
# Let us remove the 'Math score' variable
df.drop('Math score', axis=1)
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Reading score  Writing score
# 962                    none            100            100
# 625               completed             97             99
# 458                    none            100            100
# 623               completed             96             86
# 451                    none             92             97
# ..                      ...            ...            ...
# 145                    none             39             33
# 787                    none             38             32
# 17                     none             32             28
# 980                    none             24             23
# 59                     none             17             10
#
# [1000 rows x 7 columns]

# %%
# Note that we did not modify the original DataFrame
df
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# As we saw previously, we can either define a new DataFrame
df_wo_math = df.drop('Math score', axis=1)

# (let's check that everything worked as expected)
df_wo_math
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Reading score  Writing score
# 962                    none            100            100
# 625               completed             97             99
# 458                    none            100            100
# 623               completed             96             86
# 451                    none             92             97
# ..                      ...            ...            ...
# 145                    none             39             33
# 787                    none             38             32
# 17                     none             32             28
# 980                    none             24             23
# 59                     none             17             10
#
# [1000 rows x 7 columns]

# %%
# Or we can modify the original DataFrame inplace, by using the 'inplace' argument
df.drop('Math score', axis=1, inplace=True)

# %%
# (let's check it again)
df
# Out:
#      Gender Race/Ethnicity Parental level of education         Lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     Test preparation course  Reading score  Writing score
# 962                    none            100            100
# 625               completed             97             99
# 458                    none            100            100
# 623               completed             96             86
# 451                    none             92             97
# ..                      ...            ...            ...
# 145                    none             39             33
# 787                    none             38             32
# 17                     none             32             28
# 980                    none             24             23
# 59                     none             17             10
#
# [1000 rows x 7 columns]
